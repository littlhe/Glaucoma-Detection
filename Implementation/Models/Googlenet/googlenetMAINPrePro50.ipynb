# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD

# %%
# define parameters
CLASS_NUM = 2
BATCH_SIZE = 3
#EPOCH_STEPS = int(4323/BATCH_SIZE)
IMAGE_SHAPE = (224, 224, 3)
IMAGE_TRAIN = '/content/drive/MyDrive/prepro/clahee/train'
MODEL_NAME = '/content/drive/MyDrive/googlenet.h5'

# %%
# prepare data
train_datagen = ImageDataGenerator(
    rescale=1./255,
    #rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

generator_main = train_datagen.flow_from_directory(
    IMAGE_TRAIN,
    target_size=(IMAGE_SHAPE[0], IMAGE_SHAPE[1]),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

def my_generator(generator):
    while True: # keras requires all generators to be infinite
        data = next(generator)
        x = data[0]
        y = data[1], data[1], data[1]
        yield x, y

train_generator = my_generator(generator_main)
# Out:
# Found 49 images belonging to 2 classes.

# %%
# create model
def inception(x, filters):
    # 1x1
    path1 = Conv2D(filters=filters[0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)

    # 1x1->3x3
    path2 = Conv2D(filters=filters[1][0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    path2 = Conv2D(filters=filters[1][1], kernel_size=(3,3), strides=1, padding='same', activation='relu')(path2)
    
    # 1x1->5x5
    path3 = Conv2D(filters=filters[2][0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    path3 = Conv2D(filters=filters[2][1], kernel_size=(5,5), strides=1, padding='same', activation='relu')(path3)

    # 3x3->1x1
    path4 = MaxPooling2D(pool_size=(3,3), strides=1, padding='same')(x)
    path4 = Conv2D(filters=filters[3], kernel_size=(1,1), strides=1, padding='same', activation='relu')(path4)

    return Concatenate(axis=-1)([path1,path2,path3,path4])


def auxiliary(x, name=None):
    layer = AveragePooling2D(pool_size=(5,5), strides=3, padding='valid')(x)
    layer = Conv2D(filters=128, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Flatten()(layer)
    layer = Dense(units=256, activation='relu')(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=CLASS_NUM, activation='softmax', name=name)(layer)
    return layer


def googlenet():
    layer_in = Input(shape=IMAGE_SHAPE)
    
    # stage-1
    layer = Conv2D(filters=64, kernel_size=(7,7), strides=2, padding='same', activation='relu')(layer_in)
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    layer = BatchNormalization()(layer)

    # stage-2
    layer = Conv2D(filters=64, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Conv2D(filters=192, kernel_size=(3,3), strides=1, padding='same', activation='relu')(layer)
    layer = BatchNormalization()(layer)
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)

    # stage-3
    layer = inception(layer, [ 64,  (96,128), (16,32), 32]) #3a
    layer = inception(layer, [128, (128,192), (32,96), 64]) #3b
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-4
    layer = inception(layer, [192,  (96,208),  (16,48),  64]) #4a
    aux1  = auxiliary(layer, name='aux1')
    layer = inception(layer, [160, (112,224),  (24,64),  64]) #4b
    layer = inception(layer, [128, (128,256),  (24,64),  64]) #4c
    layer = inception(layer, [112, (144,288),  (32,64),  64]) #4d
    aux2  = auxiliary(layer, name='aux2')
    layer = inception(layer, [256, (160,320), (32,128), 128]) #4e
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-5
    layer = inception(layer, [256, (160,320), (32,128), 128]) #5a
    layer = inception(layer, [384, (192,384), (48,128), 128]) #5b
    layer = AveragePooling2D(pool_size=(7,7), strides=1, padding='valid')(layer)
    
    # stage-6
    layer = Flatten()(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=256, activation='linear')(layer)
    main = Dense(units=CLASS_NUM, activation='softmax', name='main')(layer)
    
    model = Model(inputs=layer_in, outputs=[main, aux1, aux2])
    
    return model

# %%
# train model
model = googlenet()
model.summary()
#model.load_weights(MODEL_NAME)
#tf.keras.utils.plot_model(model, 'GoogLeNet.png')

#optimizer = Adam(lr=2 * 1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
#optimizer = SGD(lr=1 * 1e-1, momentum=0.9, nesterov=True)
#model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

optimizer = ['Adam']
epochs = [50]
history_all = {}

for i in range(len(optimizer)):
    print('Usnig optimizer: ' + optimizer[i] + ', Epoch: ' + str(epochs[i]))
    
    model.compile(loss='categorical_crossentropy', 
                  loss_weights={'main': 1.0, 'aux1': 0.3, 'aux2': 0.3},
                  optimizer=optimizer[i], metrics=['accuracy'])
    
    train_history = model.fit_generator(
            train_generator,
            steps_per_epoch=50,
            epochs=epochs[i],
            #callbacks=[checkpoint]
            shuffle=True
            )
    
    # save history    
    if len(history_all) == 0:
        history_all = {key: [] for key in train_history.history}
    
    for key in history_all:
        history_all[key].extend(train_history.history[key])

model.save(MODEL_NAME)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_59 (Conv2D)             (None, 112, 112, 64  9472        ['input_2[0][0]']
#                                 )
#
#  max_pooling2d_13 (MaxPooling2D  (None, 56, 56, 64)  0           ['conv2d_59[0][0]']
#  )
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['max_pooling2d_13[0][0]']
#  rmalization)
#
#  conv2d_60 (Conv2D)             (None, 56, 56, 64)   4160        ['batch_normalization_2[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 56, 56, 192)  110784      ['conv2d_60[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 192)  768        ['conv2d_61[0][0]']
#  rmalization)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 28, 28, 192)  0          ['batch_normalization_3[0][0]']
#  )
#
#  conv2d_63 (Conv2D)             (None, 28, 28, 96)   18528       ['max_pooling2d_14[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 28, 28, 16)   3088        ['max_pooling2d_14[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 28, 28, 192)  0          ['max_pooling2d_14[0][0]']
#  )
#
#  conv2d_62 (Conv2D)             (None, 28, 28, 64)   12352       ['max_pooling2d_14[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 28, 28, 128)  110720      ['conv2d_63[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 28, 28, 32)   12832       ['conv2d_65[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 28, 28, 32)   6176        ['max_pooling2d_15[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 256)  0           ['conv2d_62[0][0]',
#                                                                   'conv2d_64[0][0]',
#                                                                   'conv2d_66[0][0]',
#                                                                   'conv2d_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 28, 28, 128)  32896       ['concatenate_9[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 28, 28, 32)   8224        ['concatenate_9[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 28, 28, 256)  0          ['concatenate_9[0][0]']
#  )
#
#  conv2d_68 (Conv2D)             (None, 28, 28, 128)  32896       ['concatenate_9[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 28, 28, 192)  221376      ['conv2d_69[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 28, 28, 96)   76896       ['conv2d_71[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 28, 28, 64)   16448       ['max_pooling2d_16[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 28, 28, 480)  0           ['conv2d_68[0][0]',
#                                                                   'conv2d_70[0][0]',
#                                                                   'conv2d_72[0][0]',
#                                                                   'conv2d_73[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 14, 14, 480)  0          ['concatenate_10[0][0]']
#  )
#
#  conv2d_75 (Conv2D)             (None, 14, 14, 96)   46176       ['max_pooling2d_17[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 14, 14, 16)   7696        ['max_pooling2d_17[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 14, 14, 480)  0          ['max_pooling2d_17[0][0]']
#  )
#
#  conv2d_74 (Conv2D)             (None, 14, 14, 192)  92352       ['max_pooling2d_17[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 14, 14, 208)  179920      ['conv2d_75[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 14, 14, 48)   19248       ['conv2d_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 14, 14, 64)   30784       ['max_pooling2d_18[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 14, 14, 512)  0           ['conv2d_74[0][0]',
#                                                                   'conv2d_76[0][0]',
#                                                                   'conv2d_78[0][0]',
#                                                                   'conv2d_79[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_11[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_11[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_11[0][0]']
#  )
#
#  conv2d_81 (Conv2D)             (None, 14, 14, 160)  82080       ['concatenate_11[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 14, 14, 224)  226016      ['conv2d_82[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_84[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_19[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 14, 14, 512)  0           ['conv2d_81[0][0]',
#                                                                   'conv2d_83[0][0]',
#                                                                   'conv2d_85[0][0]',
#                                                                   'conv2d_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_12[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_12[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_12[0][0]']
#  )
#
#  conv2d_87 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_12[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 14, 14, 256)  295168      ['conv2d_88[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_20[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 14, 14, 512)  0           ['conv2d_87[0][0]',
#                                                                   'conv2d_89[0][0]',
#                                                                   'conv2d_91[0][0]',
#                                                                   'conv2d_92[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 14, 14, 144)  73872       ['concatenate_13[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 14, 14, 32)   16416       ['concatenate_13[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 14, 14, 512)  0          ['concatenate_13[0][0]']
#  )
#
#  conv2d_93 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_13[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 14, 14, 288)  373536      ['conv2d_94[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 14, 14, 64)   51264       ['conv2d_96[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_21[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 14, 14, 528)  0           ['conv2d_93[0][0]',
#                                                                   'conv2d_95[0][0]',
#                                                                   'conv2d_97[0][0]',
#                                                                   'conv2d_98[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 14, 14, 160)  84640       ['concatenate_14[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 14, 14, 32)   16928       ['concatenate_14[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 14, 14, 528)  0          ['concatenate_14[0][0]']
#  )
#
#  conv2d_100 (Conv2D)            (None, 14, 14, 256)  135424      ['concatenate_14[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 14, 14, 320)  461120      ['conv2d_101[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 14, 14, 128)  102528      ['conv2d_103[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 14, 14, 128)  67712       ['max_pooling2d_22[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 14, 14, 832)  0           ['conv2d_100[0][0]',
#                                                                   'conv2d_102[0][0]',
#                                                                   'conv2d_104[0][0]',
#                                                                   'conv2d_105[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_15[0][0]']
#  )
#
#  conv2d_107 (Conv2D)            (None, 7, 7, 160)    133280      ['max_pooling2d_23[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 7, 7, 32)     26656       ['max_pooling2d_23[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D  (None, 7, 7, 832)   0           ['max_pooling2d_23[0][0]']
#  )
#
#  conv2d_106 (Conv2D)            (None, 7, 7, 256)    213248      ['max_pooling2d_23[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 7, 7, 320)    461120      ['conv2d_107[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 7, 7, 128)    102528      ['conv2d_109[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 7, 7, 128)    106624      ['max_pooling2d_24[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 7, 7, 832)    0           ['conv2d_106[0][0]',
#                                                                   'conv2d_108[0][0]',
#                                                                   'conv2d_110[0][0]',
#                                                                   'conv2d_111[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 7, 7, 192)    159936      ['concatenate_16[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 7, 7, 48)     39984       ['concatenate_16[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_16[0][0]']
#  )
#
#  conv2d_112 (Conv2D)            (None, 7, 7, 384)    319872      ['concatenate_16[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 7, 7, 384)    663936      ['conv2d_113[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 7, 7, 128)    153728      ['conv2d_115[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 7, 7, 128)    106624      ['max_pooling2d_25[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 7, 7, 1024)   0           ['conv2d_112[0][0]',
#                                                                   'conv2d_114[0][0]',
#                                                                   'conv2d_116[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 4, 4, 512)   0           ['concatenate_11[0][0]']
#  oling2D)
#
#  average_pooling2d_4 (AveragePo  (None, 4, 4, 528)   0           ['concatenate_14[0][0]']
#  oling2D)
#
#  average_pooling2d_5 (AveragePo  (None, 1, 1, 1024)  0           ['concatenate_17[0][0]']
#  oling2D)
#
#  conv2d_80 (Conv2D)             (None, 4, 4, 128)    65664       ['average_pooling2d_3[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 4, 4, 128)    67712       ['average_pooling2d_4[0][0]']
#
#  flatten_5 (Flatten)            (None, 1024)         0           ['average_pooling2d_5[0][0]']
#
#  flatten_3 (Flatten)            (None, 2048)         0           ['conv2d_80[0][0]']
#
#  flatten_4 (Flatten)            (None, 2048)         0           ['conv2d_99[0][0]']
#
#  dropout_5 (Dropout)            (None, 1024)         0           ['flatten_5[0][0]']
#
#  dense_3 (Dense)                (None, 256)          524544      ['flatten_3[0][0]']
#
#  dense_4 (Dense)                (None, 256)          524544      ['flatten_4[0][0]']
#
#  dense_5 (Dense)                (None, 256)          262400      ['dropout_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 256)          0           ['dense_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 256)          0           ['dense_4[0][0]']
#
#  main (Dense)                   (None, 2)            514         ['dense_5[0][0]']
#
#  aux1 (Dense)                   (None, 2)            514         ['dropout_3[0][0]']
#
#  aux2 (Dense)                   (None, 2)            514         ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 7,420,982
# Trainable params: 7,420,470
# Non-trainable params: 512
# __________________________________________________________________________________________________
# Usnig optimizer: Adam, Epoch: 50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# 50/50 [==============================] - 49s 903ms/step - loss: 5.1675 - main_loss: 4.4576 - aux1_loss: 0.9478 - aux2_loss: 1.4186 - main_accuracy: 0.6667 - aux1_accuracy: 0.6319 - aux2_accuracy: 0.6875
# Epoch 2/50
# 50/50 [==============================] - 45s 892ms/step - loss: 1.0029 - main_loss: 0.6244 - aux1_loss: 0.6222 - aux2_loss: 0.6393 - main_accuracy: 0.7083 - aux1_accuracy: 0.7083 - aux2_accuracy: 0.7083
# Epoch 3/50
# 50/50 [==============================] - 44s 883ms/step - loss: 0.9708 - main_loss: 0.6051 - aux1_loss: 0.6124 - aux2_loss: 0.6066 - main_accuracy: 0.7153 - aux1_accuracy: 0.7153 - aux2_accuracy: 0.7153
# Epoch 4/50
# 50/50 [==============================] - 44s 889ms/step - loss: 1.0853 - main_loss: 0.6686 - aux1_loss: 0.7044 - aux2_loss: 0.6844 - main_accuracy: 0.6458 - aux1_accuracy: 0.6389 - aux2_accuracy: 0.6458
# Epoch 5/50
# 50/50 [==============================] - 44s 883ms/step - loss: 0.9943 - main_loss: 0.6149 - aux1_loss: 0.6475 - aux2_loss: 0.6171 - main_accuracy: 0.7014 - aux1_accuracy: 0.6944 - aux2_accuracy: 0.7014
# Epoch 6/50
# 50/50 [==============================] - 44s 888ms/step - loss: 0.9448 - main_loss: 0.5892 - aux1_loss: 0.5866 - aux2_loss: 0.5987 - main_accuracy: 0.7292 - aux1_accuracy: 0.7292 - aux2_accuracy: 0.7292
# Epoch 7/50
# 50/50 [==============================] - 45s 890ms/step - loss: 1.0352 - main_loss: 0.6462 - aux1_loss: 0.6480 - aux2_loss: 0.6484 - main_accuracy: 0.6667 - aux1_accuracy: 0.6736 - aux2_accuracy: 0.6667
# Epoch 8/50
# 50/50 [==============================] - 45s 895ms/step - loss: 0.9750 - main_loss: 0.6144 - aux1_loss: 0.5939 - aux2_loss: 0.6082 - main_accuracy: 0.7014 - aux1_accuracy: 0.7014 - aux2_accuracy: 0.7014
# Epoch 9/50
# 50/50 [==============================] - 45s 891ms/step - loss: 0.9903 - main_loss: 0.6251 - aux1_loss: 0.5948 - aux2_loss: 0.6226 - main_accuracy: 0.6875 - aux1_accuracy: 0.6667 - aux2_accuracy: 0.6875
# Epoch 10/50
# 50/50 [==============================] - 45s 895ms/step - loss: 0.9587 - main_loss: 0.6084 - aux1_loss: 0.5623 - aux2_loss: 0.6056 - main_accuracy: 0.7153 - aux1_accuracy: 0.7083 - aux2_accuracy: 0.7153
# Epoch 11/50
# 50/50 [==============================] - 45s 889ms/step - loss: 1.0459 - main_loss: 0.6706 - aux1_loss: 0.6101 - aux2_loss: 0.6410 - main_accuracy: 0.6458 - aux1_accuracy: 0.6875 - aux2_accuracy: 0.6875
# Epoch 12/50
# 50/50 [==============================] - 45s 890ms/step - loss: 1.0006 - main_loss: 0.6287 - aux1_loss: 0.6016 - aux2_loss: 0.6383 - main_accuracy: 0.6875 - aux1_accuracy: 0.6875 - aux2_accuracy: 0.6875
# Epoch 13/50
# 50/50 [==============================] - 44s 887ms/step - loss: 1.0019 - main_loss: 0.6292 - aux1_loss: 0.6227 - aux2_loss: 0.6197 - main_accuracy: 0.6875 - aux1_accuracy: 0.6736 - aux2_accuracy: 0.6806
# Epoch 14/50
# 50/50 [==============================] - 44s 889ms/step - loss: 1.0142 - main_loss: 0.6330 - aux1_loss: 0.6309 - aux2_loss: 0.6398 - main_accuracy: 0.6944 - aux1_accuracy: 0.7153 - aux2_accuracy: 0.6944
# Epoch 15/50
# 50/50 [==============================] - 44s 888ms/step - loss: 0.9770 - main_loss: 0.6123 - aux1_loss: 0.6037 - aux2_loss: 0.6120 - main_accuracy: 0.7014 - aux1_accuracy: 0.7083 - aux2_accuracy: 0.6875
# Epoch 16/50
# 50/50 [==============================] - 44s 889ms/step - loss: 0.9918 - main_loss: 0.6212 - aux1_loss: 0.6163 - aux2_loss: 0.6190 - main_accuracy: 0.6806 - aux1_accuracy: 0.7083 - aux2_accuracy: 0.7083
# Epoch 17/50
# 50/50 [==============================] - 45s 898ms/step - loss: 0.9915 - main_loss: 0.6256 - aux1_loss: 0.5987 - aux2_loss: 0.6210 - main_accuracy: 0.6918 - aux1_accuracy: 0.6918 - aux2_accuracy: 0.6918
# Epoch 18/50
# 50/50 [==============================] - 45s 913ms/step - loss: 1.0030 - main_loss: 0.6395 - aux1_loss: 0.6085 - aux2_loss: 0.6031 - main_accuracy: 0.6806 - aux1_accuracy: 0.7361 - aux2_accuracy: 0.7014
# Epoch 19/50
# 50/50 [==============================] - 45s 895ms/step - loss: 0.9603 - main_loss: 0.6121 - aux1_loss: 0.5717 - aux2_loss: 0.5892 - main_accuracy: 0.7083 - aux1_accuracy: 0.7361 - aux2_accuracy: 0.7014
# Epoch 20/50
# 50/50 [==============================] - 45s 890ms/step - loss: 0.9652 - main_loss: 0.6332 - aux1_loss: 0.5693 - aux2_loss: 0.5375 - main_accuracy: 0.6806 - aux1_accuracy: 0.7153 - aux2_accuracy: 0.7014
# Epoch 21/50
# 50/50 [==============================] - 44s 884ms/step - loss: 0.9470 - main_loss: 0.6147 - aux1_loss: 0.5477 - aux2_loss: 0.5600 - main_accuracy: 0.7083 - aux1_accuracy: 0.7361 - aux2_accuracy: 0.7292
# Epoch 22/50
# 50/50 [==============================] - 45s 893ms/step - loss: 0.9439 - main_loss: 0.6297 - aux1_loss: 0.5344 - aux2_loss: 0.5128 - main_accuracy: 0.6667 - aux1_accuracy: 0.7778 - aux2_accuracy: 0.7292
# Epoch 23/50
# 50/50 [==============================] - 45s 890ms/step - loss: 0.9463 - main_loss: 0.6060 - aux1_loss: 0.5840 - aux2_loss: 0.5502 - main_accuracy: 0.6875 - aux1_accuracy: 0.7083 - aux2_accuracy: 0.7014
# Epoch 24/50
# 50/50 [==============================] - 45s 895ms/step - loss: 0.8683 - main_loss: 0.5790 - aux1_loss: 0.4857 - aux2_loss: 0.4785 - main_accuracy: 0.7431 - aux1_accuracy: 0.7847 - aux2_accuracy: 0.8056
# Epoch 25/50
# 50/50 [==============================] - 45s 893ms/step - loss: 0.9335 - main_loss: 0.5898 - aux1_loss: 0.5995 - aux2_loss: 0.5461 - main_accuracy: 0.6597 - aux1_accuracy: 0.7361 - aux2_accuracy: 0.7708
# Epoch 26/50
# 50/50 [==============================] - 45s 899ms/step - loss: 0.9298 - main_loss: 0.6169 - aux1_loss: 0.5251 - aux2_loss: 0.5181 - main_accuracy: 0.6806 - aux1_accuracy: 0.7639 - aux2_accuracy: 0.7222
# Epoch 27/50
# 50/50 [==============================] - 45s 890ms/step - loss: 0.8086 - main_loss: 0.5236 - aux1_loss: 0.4726 - aux2_loss: 0.4773 - main_accuracy: 0.7083 - aux1_accuracy: 0.7222 - aux2_accuracy: 0.7639
# Epoch 28/50
# 50/50 [==============================] - 45s 892ms/step - loss: 0.9208 - main_loss: 0.5953 - aux1_loss: 0.5617 - aux2_loss: 0.5233 - main_accuracy: 0.7083 - aux1_accuracy: 0.7639 - aux2_accuracy: 0.7708
# Epoch 29/50
# 50/50 [==============================] - 44s 883ms/step - loss: 0.8299 - main_loss: 0.5592 - aux1_loss: 0.4804 - aux2_loss: 0.4217 - main_accuracy: 0.6875 - aux1_accuracy: 0.7569 - aux2_accuracy: 0.8056
# Epoch 30/50
# 50/50 [==============================] - 44s 882ms/step - loss: 1.0821 - main_loss: 0.6346 - aux1_loss: 0.8658 - aux2_loss: 0.6258 - main_accuracy: 0.6875 - aux1_accuracy: 0.7083 - aux2_accuracy: 0.7083
# Epoch 31/50
# 50/50 [==============================] - 44s 882ms/step - loss: 1.0016 - main_loss: 0.6308 - aux1_loss: 0.6091 - aux2_loss: 0.6269 - main_accuracy: 0.6944 - aux1_accuracy: 0.7083 - aux2_accuracy: 0.6736
# Epoch 32/50
# 50/50 [==============================] - 44s 883ms/step - loss: 0.8522 - main_loss: 0.5725 - aux1_loss: 0.4980 - aux2_loss: 0.4345 - main_accuracy: 0.6875 - aux1_accuracy: 0.7986 - aux2_accuracy: 0.8125
# Epoch 33/50
# 50/50 [==============================] - 44s 881ms/step - loss: 0.9477 - main_loss: 0.6091 - aux1_loss: 0.5631 - aux2_loss: 0.5658 - main_accuracy: 0.6944 - aux1_accuracy: 0.7778 - aux2_accuracy: 0.7014
# Epoch 34/50
# 50/50 [==============================] - 45s 893ms/step - loss: 0.8406 - main_loss: 0.5529 - aux1_loss: 0.4914 - aux2_loss: 0.4676 - main_accuracy: 0.7055 - aux1_accuracy: 0.7192 - aux2_accuracy: 0.7603
# Epoch 35/50
# 50/50 [==============================] - 44s 898ms/step - loss: 0.7961 - main_loss: 0.5310 - aux1_loss: 0.4417 - aux2_loss: 0.4419 - main_accuracy: 0.7222 - aux1_accuracy: 0.7847 - aux2_accuracy: 0.8125
# Epoch 36/50
# 50/50 [==============================] - 44s 883ms/step - loss: 0.7888 - main_loss: 0.5213 - aux1_loss: 0.4232 - aux2_loss: 0.4684 - main_accuracy: 0.6944 - aux1_accuracy: 0.8056 - aux2_accuracy: 0.7917
# Epoch 37/50
# 50/50 [==============================] - 44s 888ms/step - loss: 0.8059 - main_loss: 0.5311 - aux1_loss: 0.4773 - aux2_loss: 0.4388 - main_accuracy: 0.7083 - aux1_accuracy: 0.7778 - aux2_accuracy: 0.7569
# Epoch 38/50
# 50/50 [==============================] - 44s 880ms/step - loss: 0.7286 - main_loss: 0.4888 - aux1_loss: 0.3938 - aux2_loss: 0.4055 - main_accuracy: 0.8125 - aux1_accuracy: 0.8264 - aux2_accuracy: 0.8542
# Epoch 39/50
# 50/50 [==============================] - 44s 886ms/step - loss: 0.8013 - main_loss: 0.5383 - aux1_loss: 0.4117 - aux2_loss: 0.4648 - main_accuracy: 0.7917 - aux1_accuracy: 0.8125 - aux2_accuracy: 0.7917
# Epoch 40/50
# 50/50 [==============================] - 44s 880ms/step - loss: 0.9158 - main_loss: 0.5998 - aux1_loss: 0.5385 - aux2_loss: 0.5147 - main_accuracy: 0.7569 - aux1_accuracy: 0.7708 - aux2_accuracy: 0.7639
# Epoch 41/50
# 50/50 [==============================] - 44s 881ms/step - loss: 0.7813 - main_loss: 0.5045 - aux1_loss: 0.4457 - aux2_loss: 0.4768 - main_accuracy: 0.7847 - aux1_accuracy: 0.8333 - aux2_accuracy: 0.8264
# Epoch 42/50
# 50/50 [==============================] - 44s 880ms/step - loss: 0.8991 - main_loss: 0.5681 - aux1_loss: 0.5287 - aux2_loss: 0.5747 - main_accuracy: 0.7153 - aux1_accuracy: 0.7292 - aux2_accuracy: 0.7014
# Epoch 43/50
# 50/50 [==============================] - 44s 879ms/step - loss: 0.7262 - main_loss: 0.4804 - aux1_loss: 0.3981 - aux2_loss: 0.4212 - main_accuracy: 0.7847 - aux1_accuracy: 0.8125 - aux2_accuracy: 0.8194
# Epoch 44/50
# 50/50 [==============================] - 44s 880ms/step - loss: 0.8686 - main_loss: 0.5584 - aux1_loss: 0.4996 - aux2_loss: 0.5344 - main_accuracy: 0.6667 - aux1_accuracy: 0.7431 - aux2_accuracy: 0.7361
# Epoch 45/50
# 50/50 [==============================] - 44s 886ms/step - loss: 0.6626 - main_loss: 0.4297 - aux1_loss: 0.3832 - aux2_loss: 0.3930 - main_accuracy: 0.7986 - aux1_accuracy: 0.8125 - aux2_accuracy: 0.8194
# Epoch 46/50
# 50/50 [==============================] - 45s 891ms/step - loss: 0.7180 - main_loss: 0.4573 - aux1_loss: 0.4548 - aux2_loss: 0.4142 - main_accuracy: 0.8056 - aux1_accuracy: 0.8472 - aux2_accuracy: 0.8681
# Epoch 47/50
# 50/50 [==============================] - 45s 890ms/step - loss: 0.6761 - main_loss: 0.4736 - aux1_loss: 0.3054 - aux2_loss: 0.3694 - main_accuracy: 0.7917 - aux1_accuracy: 0.8819 - aux2_accuracy: 0.8750
# Epoch 48/50
# 50/50 [==============================] - 44s 889ms/step - loss: 0.6735 - main_loss: 0.4559 - aux1_loss: 0.3051 - aux2_loss: 0.4204 - main_accuracy: 0.8264 - aux1_accuracy: 0.8611 - aux2_accuracy: 0.8056
# Epoch 49/50
# 50/50 [==============================] - 44s 885ms/step - loss: 0.4608 - main_loss: 0.2889 - aux1_loss: 0.2952 - aux2_loss: 0.2778 - main_accuracy: 0.9028 - aux1_accuracy: 0.8681 - aux2_accuracy: 0.8889
# Epoch 50/50
# 50/50 [==============================] - 44s 885ms/step - loss: 0.5775 - main_loss: 0.3921 - aux1_loss: 0.2882 - aux2_loss: 0.3296 - main_accuracy: 0.8194 - aux1_accuracy: 0.8403 - aux2_accuracy: 0.8125

# %%
# show train history
def show_train_history(history, xlabel, ylabel, train):
    for item in train:
        plt.plot(history[item])
    plt.title('Train History')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend(train, loc='upper left')
    plt.show()

show_train_history(history_all, 'Epoch', 'Accuracy', ('main_accuracy', 'aux1_accuracy'))
show_train_history(history_all, 'Epoch', 'Loss', ('main_loss', 'aux1_loss'))

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()
