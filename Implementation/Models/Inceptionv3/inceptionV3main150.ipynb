# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
class LogisticEndpoint(keras.layers.Layer):
    def __init__(self, name=None):
        super(LogisticEndpoint, self).__init__(name=name)
        self.loss_fn = keras.losses.BinaryCrossentropy(from_logits=True)
        self.accuracy_fn = keras.metrics.BinaryAccuracy()

    def call(self, targets, logits, sample_weights=None):
        # Compute the training-time loss value and add it
        # to the layer using `self.add_loss()`.
        loss = self.loss_fn(targets, logits, sample_weights)
        self.add_loss(loss)

        # Log accuracy as a metric and add it
        # to the layer using `self.add_metric()`.
        acc = self.accuracy_fn(targets, logits, sample_weights)
        self.add_metric(acc, name="accuracy")

        # Return the inference-time prediction tensor (for `.predict()`).
        return tf.nn.softmax(logits)

# %%
layer = LogisticEndpoint()

# %%
targets = tf.ones((2, 2))
logits = tf.ones((2, 2))
y = layer(targets, logits)

# %%
print("layer.metrics:", layer.metrics)
print("current accuracy value:", float(layer.metrics[0].result()))
inputs = keras.Input(shape=(3,), name="inputs")
targets = keras.Input(shape=(10,), name="targets")
logits = keras.layers.Dense(10)(inputs)
predictions = LogisticEndpoint(name="predictions")(logits, targets)
# Out:
# layer.metrics: [<keras.metrics.BinaryAccuracy object at 0x7fb27db6c950>]
# current accuracy value: 1.0

# %%
model = keras.Model(inputs=[inputs, targets], outputs=predictions)
model.compile(optimizer="adam")

# %%
data = {
    "inputs": np.random.random((3, 3)),
    "targets": np.random.random((3, 10)),
}
model.fit(data)
# Out:
# 1/1 [==============================] - 1s 550ms/step - loss: 0.9280 - binary_accuracy: 0.0000e+00

# %%
#import tensorflow as tf
#from tensorflow import keras
#from tensorflow.keras import layers

import tensorflow as tf
from tensorflow import keras
import numpy as np

#from keras.models import Model
#from keras.layers import Input
#from keras.layers import Conv2D
#from keras.layers import MaxPooling2D
#from keras.layers.merge import concatenate
#from keras.utils import plot_model

# %%
#inception naive version

def inception_module(x, f1, f2, f3):
	# 1x1 conv
	conv1 =  keras.layers.Conv2D(f1, (1,1), padding='same', activation='relu')(x)
	# 3x3 conv
	conv3 = keras.layers.Conv2D(f2, (3,3), padding='same', activation='relu')(x)
	# 5x5 conv
	conv5 = keras.layers.Conv2D(f3, (5,5), padding='same', activation='relu')(x)
	# 3x3 max pooling
	pool = keras.layers.MaxPooling2D((3,3), strides=(1,1), padding='same')(x)
	# concatenate filters
	out = keras.layers.merge.concatenate([conv1, conv3, conv5, pool])
	return out

# %%
img_input = keras.Input(shape=(299, 299, 3))
classes=2
WEIGHTS_PATH = 'https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'
WEIGHTS_PATH = 'inception_v3_weights_tf_dim_ordering_tf_kernels.h5'
WEIGHTS_PATH = 'inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'
channel_axis=3

# %%
# Use the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Drishti Vgg16/prepro/clahee/train',
                                                 target_size = (224, 224),
                                                 batch_size = 7,
                                                 class_mode = 'categorical')
# Out:
# Found 49 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Drishti Vgg16/prepro/clahee/test',
                                            target_size = (224, 224),
                                            batch_size = 5,
                                            class_mode = 'categorical')
# Out:
# Found 31 images belonging to 2 classes.

# %%
def conv2d_bn(x,filters,num_row,num_col,padding='same',strides=(1, 1)):
   
    x = keras.layers.Conv2D(filters, (num_row, num_col),strides=strides,padding=padding)(x)
    x = keras.layers.BatchNormalization(axis=3, scale=False)(x)
    x = keras.layers.Activation('relu')(x)
    return x

# %%
def inc_block_a(x):    
    branch1x1 = conv2d_bn(x, 64, 1, 1)  # 64 filters of 1*1

    branch5x5 = conv2d_bn(x, 48, 1, 1)  #48 filters of 1*1
    branch5x5 = conv2d_bn(branch5x5, 64, 5, 5)

    branch3x3dbl = conv2d_bn(x, 64, 1, 1)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3)

    branch_pool = keras.layers.AveragePooling2D((3, 3), strides=(1, 1), padding='same')(x)
    branch_pool = conv2d_bn(branch_pool, 32, 1, 1)
    x = keras.layers.concatenate([branch1x1, branch5x5, branch3x3dbl, branch_pool], axis=channel_axis)
    return x

# %%
def reduction_block_a(x):  
    branch3x3 = conv2d_bn(x, 384, 3, 3, strides=(2, 2), padding='valid')

    branch3x3dbl = conv2d_bn(x, 64, 1, 1)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3)
    branch3x3dbl = conv2d_bn(branch3x3dbl, 96, 3, 3, strides=(2, 2), padding='valid')

    branch_pool = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)
    x = keras.layers.concatenate([branch3x3, branch3x3dbl, branch_pool],axis=channel_axis)
    return x

# %%
# 17 x 17 x 768
def inc_block_b(x):
    branch1x1 = conv2d_bn(x, 192, 1, 1)

    branch7x7 = conv2d_bn(x, 128, 1, 1)
    branch7x7 = conv2d_bn(branch7x7, 128, 1, 7)
    branch7x7 = conv2d_bn(branch7x7, 192, 7, 1)

    branch7x7dbl = conv2d_bn(x, 128, 1, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 128, 7, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 128, 1, 7)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 128, 7, 1)
    branch7x7dbl = conv2d_bn(branch7x7dbl, 192, 1, 7)

    branch_pool = keras.layers.AveragePooling2D((3, 3), strides=(1, 1),padding='same')(x)
    branch_pool = conv2d_bn(branch_pool, 192, 1, 1)
    x = keras.layers.concatenate([branch1x1, branch7x7, branch7x7dbl, branch_pool], axis=channel_axis)
    return x

# %%
# mixed 8: 8 x 8 x 1280
def reduction_block_b(x): 
    branch3x3 = conv2d_bn(x, 192, 1, 1)
    branch3x3 = conv2d_bn(branch3x3, 320, 3, 3,strides=(2, 2), padding='valid')

    branch7x7x3 = conv2d_bn(x, 192, 1, 1)
    branch7x7x3 = conv2d_bn(branch7x7x3, 192, 1, 7)
    branch7x7x3 = conv2d_bn(branch7x7x3, 192, 7, 1)
    branch7x7x3 = conv2d_bn( branch7x7x3, 192, 3, 3, strides=(2, 2), padding='valid')

    branch_pool = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)
    x = keras.layers.concatenate([branch3x3, branch7x7x3, branch_pool], axis=channel_axis)
    return x

# %%
def inc_block_c(x):        
        branch1x1 = conv2d_bn(x, 320, 1, 1)

        branch3x3 = conv2d_bn(x, 384, 1, 1)
        branch3x3_1 = conv2d_bn(branch3x3, 384, 1, 3)
        branch3x3_2 = conv2d_bn(branch3x3, 384, 3, 1)
        branch3x3 = keras.layers.concatenate([branch3x3_1, branch3x3_2],axis=channel_axis)

        branch3x3dbl = conv2d_bn(x, 448, 1, 1)
        branch3x3dbl = conv2d_bn(branch3x3dbl, 384, 3, 3)
        branch3x3dbl_1 = conv2d_bn(branch3x3dbl, 384, 1, 3)
        branch3x3dbl_2 = conv2d_bn(branch3x3dbl, 384, 3, 1)
        branch3x3dbl = keras.layers.concatenate([branch3x3dbl_1, branch3x3dbl_2], axis=channel_axis)

        branch_pool = keras.layers.AveragePooling2D((3, 3), strides=(1, 1), padding='same')(x)
        branch_pool = conv2d_bn(branch_pool, 192, 1, 1)
        x = keras.layers.concatenate( [branch1x1, branch3x3, branch3x3dbl, branch_pool],axis=channel_axis)
        return x

# %%
img_input = keras.Input(shape=(299, 299, 3))  #shape=(None, 299, 299, 3)

# %%
# input image size: 299 x 299 x 3
x = conv2d_bn(img_input, 32, 3, 3, strides=(2, 2), padding='valid') # 149 x 149 x 32
x = conv2d_bn(x, 32, 3, 3, padding='valid')  # 147 x 147 x 32
x = conv2d_bn(x, 64, 3, 3) # 147 x 147 x 64

x = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)   # 73  x 73 x 64
x = conv2d_bn(x, 80, 1, 1, padding='valid') # 73 x 73 x 80
x = conv2d_bn(x, 192, 3, 3, padding='valid')  # 71 x 71 x 192
x = keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(x)  # 35 x 35 x 192


x=inc_block_a(x) #35, 35, 256
x=inc_block_a(x) #35, 35, 256
x=inc_block_a(x) #35, 35, 256

x=reduction_block_a(x) #17, 17, 736

x=inc_block_b(x) #17, 17, 768
x=inc_block_b(x) #17, 17, 768
x=inc_block_b(x) #17, 17, 768
x=inc_block_b(x) #17, 17, 768

x=reduction_block_b(x) #shape=(None, 8, 8, 1280)

x=inc_block_c(x) # shape=(None, 8, 8, 2048) 
x=inc_block_c(x) # shape=(None, 8, 8, 2048) 

x = keras.layers.GlobalAveragePooling2D(name='avg_pool')(x) # shape=(None, 2048)

x = keras.layers.Dense(classes, activation='softmax', name='predictions')(x) #shape=(None, 1000) 



# Create model.
inputs = img_input
model =  keras.Model(inputs, x, name='inception_v3')
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  896         ['input_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9248        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18496       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5200        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138432      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9264        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55392       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76864       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   83040       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 32)   6176        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_11[0][0]']
#
#  concatenate (Concatenate)      (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 64)   16448       ['concatenate[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 48)   12336       ['concatenate[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['concatenate[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   16448       ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   76864       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 96)   83040       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 32)   8224        ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_18[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 35, 35, 256)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 64)   16448       ['concatenate_1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 48)   12336       ['concatenate_1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 256)  0          ['concatenate_1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   16448       ['concatenate_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 64)   76864       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 96)   83040       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 32)   8224        ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 32)  96          ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_25[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 35, 35, 256)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 64)   16448       ['concatenate_2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 17, 17, 384)  885120      ['concatenate_2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 17, 17, 96)   83040       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 17, 17, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 17, 17, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 17, 17, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 256)  0          ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 17, 17, 736)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 17, 17, 128)  94336       ['concatenate_3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 17, 17, 128)  94336       ['concatenate_3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 17, 17, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 17, 17, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 17, 17, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 17, 17, 736)  0          ['concatenate_3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 17, 17, 192)  141504      ['concatenate_3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 17, 17, 192)  172224      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 17, 17, 192)  172224      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 192)  141504      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 17, 17, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 17, 17, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_39[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 17, 17, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 128)  98432       ['concatenate_4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 128)  384        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 128)  384        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 17, 17, 128)  98432       ['concatenate_4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 17, 17, 128)  384        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 128)  384        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 128)  384        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 128)  384        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 17, 17, 768)  0          ['concatenate_4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 17, 17, 192)  147648      ['concatenate_4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 192)  172224      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 192)  172224      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 192)  147648      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 17, 17, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_49[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 17, 17, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 128)  98432       ['concatenate_5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 17, 17, 128)  384        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 17, 17, 128)  384        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 128)  98432       ['concatenate_5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 128)  384        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 17, 17, 128)  384        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 128)  114816      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 128)  384        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 128)  384        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 17, 17, 768)  0          ['concatenate_5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 192)  147648      ['concatenate_5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 192)  172224      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 192)  172224      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 192)  147648      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 17, 17, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 17, 17, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 17, 17, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_59[0][0]']
# ...
#
#  batch_normalization_80 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 8, 8, 384)    491904      ['concatenate_8[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 8, 8, 384)    1548672     ['activation_80[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_81 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 8, 8, 384)    442752      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 8, 8, 384)    442752      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 8, 8, 384)    442752      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 384)    442752      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 8, 8, 1280)  0           ['concatenate_8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 8, 8, 320)    409920      ['concatenate_8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 192)    245952      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 8, 8, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_76[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 8, 8, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 8, 8, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_84[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 8, 8, 2048)   0           ['activation_76[0][0]',
#                                                                   'concatenate_9[0][0]',
#                                                                   'concatenate_10[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 448)    917952      ['concatenate_11[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 384)    786816      ['concatenate_11[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 384)    1548672     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442752      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 384)    442752      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    442752      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442752      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['concatenate_11[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 320)    655680      ['concatenate_11[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 192)    393408      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_93[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'concatenate_12[0][0]',
#                                                                   'concatenate_13[0][0]',
#                                                                   'activation_93[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['concatenate_14[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 2)            4098        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 20,033,378
# Trainable params: 20,000,610
# Non-trainable params: 32,768
# __________________________________________________________________________________________________

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# fit the model
# Run the cell. It will take some time to execute
r = model.fit(
  training_set,
  validation_data=test_set,
  epochs=150,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# Epoch 1/150
# 7/7 [==============================] - 47s 5s/step - loss: 2.3490 - accuracy: 0.4898 - val_loss: 0.8130 - val_accuracy: 0.2581
# Epoch 2/150
# 7/7 [==============================] - 24s 4s/step - loss: 1.1769 - accuracy: 0.6122 - val_loss: 0.5872 - val_accuracy: 0.7419
# Epoch 3/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.7124 - accuracy: 0.6122 - val_loss: 1.1210 - val_accuracy: 0.2581
# Epoch 4/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.7760 - accuracy: 0.6122 - val_loss: 1.3932 - val_accuracy: 0.2581
# Epoch 5/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.7663 - accuracy: 0.6735 - val_loss: 1.1177 - val_accuracy: 0.2581
# Epoch 6/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.8189 - accuracy: 0.6327 - val_loss: 2.0134 - val_accuracy: 0.2581
# Epoch 7/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.7578 - accuracy: 0.6735 - val_loss: 1.3743 - val_accuracy: 0.2581
# Epoch 8/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.5890 - accuracy: 0.7959 - val_loss: 1.1013 - val_accuracy: 0.2581
# Epoch 9/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.4941 - accuracy: 0.7143 - val_loss: 0.8113 - val_accuracy: 0.2581
# Epoch 10/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.5903 - accuracy: 0.6735 - val_loss: 0.8617 - val_accuracy: 0.2581
# Epoch 11/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.4886 - accuracy: 0.7551 - val_loss: 0.5540 - val_accuracy: 0.8065
# Epoch 12/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.5284 - accuracy: 0.7347 - val_loss: 0.6414 - val_accuracy: 0.7419
# Epoch 13/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.4369 - accuracy: 0.8163 - val_loss: 0.6584 - val_accuracy: 0.7419
# Epoch 14/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.4785 - accuracy: 0.7959 - val_loss: 10.2444 - val_accuracy: 0.7419
# Epoch 15/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.7740 - accuracy: 0.5918 - val_loss: 7.4005 - val_accuracy: 0.7419
# Epoch 16/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.6929 - accuracy: 0.6327 - val_loss: 1.1259 - val_accuracy: 0.7419
# Epoch 17/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.5722 - accuracy: 0.7143 - val_loss: 0.6662 - val_accuracy: 0.7419
# Epoch 18/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.4536 - accuracy: 0.7755 - val_loss: 15.6804 - val_accuracy: 0.2581
# Epoch 19/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.4574 - accuracy: 0.7755 - val_loss: 12.0939 - val_accuracy: 0.7419
# Epoch 20/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.4442 - accuracy: 0.7347 - val_loss: 12.2458 - val_accuracy: 0.7419
# Epoch 21/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.3960 - accuracy: 0.7959 - val_loss: 7.4336 - val_accuracy: 0.7419
# Epoch 22/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.5163 - accuracy: 0.7551 - val_loss: 1.7913 - val_accuracy: 0.7419
# Epoch 23/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.3951 - accuracy: 0.8163 - val_loss: 2.4379 - val_accuracy: 0.7419
# Epoch 24/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.4424 - accuracy: 0.7755 - val_loss: 0.6033 - val_accuracy: 0.7419
# Epoch 25/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.5448 - accuracy: 0.7143 - val_loss: 0.6832 - val_accuracy: 0.7419
# Epoch 26/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.3804 - accuracy: 0.8571 - val_loss: 1.8866 - val_accuracy: 0.2581
# Epoch 27/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.2846 - accuracy: 0.8980 - val_loss: 5.2242 - val_accuracy: 0.2581
# Epoch 28/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.3787 - accuracy: 0.8367 - val_loss: 4.3334 - val_accuracy: 0.2581
# Epoch 29/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.4140 - accuracy: 0.8980 - val_loss: 2.3812 - val_accuracy: 0.2581
# Epoch 30/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.3482 - accuracy: 0.8571 - val_loss: 1.1825 - val_accuracy: 0.2903
# Epoch 31/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.3816 - accuracy: 0.7755 - val_loss: 1.0539 - val_accuracy: 0.2581
# Epoch 32/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.3012 - accuracy: 0.9184 - val_loss: 1.5945 - val_accuracy: 0.2581
# Epoch 33/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.3572 - accuracy: 0.8367 - val_loss: 1.3200 - val_accuracy: 0.2581
# Epoch 34/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.2932 - accuracy: 0.8367 - val_loss: 1.6412 - val_accuracy: 0.2581
# Epoch 35/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.3915 - accuracy: 0.8571 - val_loss: 5.5964 - val_accuracy: 0.2581
# Epoch 36/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.2755 - accuracy: 0.8980 - val_loss: 2.9184 - val_accuracy: 0.2581
# Epoch 37/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.3637 - accuracy: 0.8367 - val_loss: 0.8035 - val_accuracy: 0.3226
# Epoch 38/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.4058 - accuracy: 0.8980 - val_loss: 0.8237 - val_accuracy: 0.7419
# Epoch 39/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.4372 - accuracy: 0.7755 - val_loss: 1.5018 - val_accuracy: 0.2581
# Epoch 40/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.5609 - accuracy: 0.7551 - val_loss: 23.4763 - val_accuracy: 0.4194
# Epoch 41/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.4932 - accuracy: 0.7143 - val_loss: 34.6574 - val_accuracy: 0.7097
# Epoch 42/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.5670 - accuracy: 0.7143 - val_loss: 138.1158 - val_accuracy: 0.2581
# Epoch 43/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.4091 - accuracy: 0.7959 - val_loss: 36.9257 - val_accuracy: 0.3226
# Epoch 44/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.3147 - accuracy: 0.8980 - val_loss: 7.2915 - val_accuracy: 0.6774
# Epoch 45/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.2303 - accuracy: 0.8776 - val_loss: 12.3676 - val_accuracy: 0.4839
# Epoch 46/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1607 - accuracy: 0.9592 - val_loss: 1.8754 - val_accuracy: 0.4516
# Epoch 47/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.2968 - accuracy: 0.8980 - val_loss: 3.6079 - val_accuracy: 0.2903
# Epoch 48/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.3983 - accuracy: 0.7959 - val_loss: 1.8890 - val_accuracy: 0.3548
# Epoch 49/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.3786 - accuracy: 0.8980 - val_loss: 1.7065 - val_accuracy: 0.3226
# Epoch 50/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.4008 - accuracy: 0.8163 - val_loss: 2.4938 - val_accuracy: 0.2581
# Epoch 51/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.2928 - accuracy: 0.8571 - val_loss: 1.6395 - val_accuracy: 0.2903
# Epoch 52/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.4061 - accuracy: 0.8571 - val_loss: 1.2678 - val_accuracy: 0.2903
# Epoch 53/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.3971 - accuracy: 0.8163 - val_loss: 1.2401 - val_accuracy: 0.2903
# Epoch 54/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.2225 - accuracy: 0.8980 - val_loss: 2.1610 - val_accuracy: 0.2581
# Epoch 55/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.2036 - accuracy: 0.9184 - val_loss: 2.3457 - val_accuracy: 0.2581
# Epoch 56/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1053 - accuracy: 1.0000 - val_loss: 2.8476 - val_accuracy: 0.2581
# Epoch 57/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1672 - accuracy: 0.9184 - val_loss: 2.6328 - val_accuracy: 0.2581
# Epoch 58/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1409 - accuracy: 0.9592 - val_loss: 2.0574 - val_accuracy: 0.3871
# Epoch 59/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.3728 - accuracy: 0.8367 - val_loss: 2.7887 - val_accuracy: 0.3871
# Epoch 60/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1808 - accuracy: 0.9388 - val_loss: 0.6722 - val_accuracy: 0.7419
# Epoch 61/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.2488 - accuracy: 0.9184 - val_loss: 0.7632 - val_accuracy: 0.6129
# Epoch 62/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1697 - accuracy: 0.9184 - val_loss: 1.2874 - val_accuracy: 0.4839
# Epoch 63/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1429 - accuracy: 0.9388 - val_loss: 1.7271 - val_accuracy: 0.4194
# Epoch 64/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0978 - accuracy: 0.9796 - val_loss: 1.7534 - val_accuracy: 0.4839
# Epoch 65/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1463 - accuracy: 0.9184 - val_loss: 1.3335 - val_accuracy: 0.5806
# Epoch 66/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.2013 - accuracy: 0.8980 - val_loss: 0.8832 - val_accuracy: 0.6452
# Epoch 67/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.4417 - accuracy: 0.8776 - val_loss: 1.6896 - val_accuracy: 0.3871
# Epoch 68/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1144 - accuracy: 0.9388 - val_loss: 2.1941 - val_accuracy: 0.2581
# Epoch 69/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0904 - accuracy: 0.9592 - val_loss: 2.0451 - val_accuracy: 0.3226
# Epoch 70/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.0907 - accuracy: 0.9592 - val_loss: 1.9254 - val_accuracy: 0.3548
# Epoch 71/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.0807 - accuracy: 0.9592 - val_loss: 1.5000 - val_accuracy: 0.5484
# Epoch 72/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.4567 - accuracy: 0.8367 - val_loss: 0.8462 - val_accuracy: 0.7419
# Epoch 73/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.2800 - accuracy: 0.8776 - val_loss: 1.4131 - val_accuracy: 0.6129
# Epoch 74/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.3608 - accuracy: 0.8980 - val_loss: 1.4107 - val_accuracy: 0.6452
# Epoch 75/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.2297 - accuracy: 0.8776 - val_loss: 1.6203 - val_accuracy: 0.7097
# Epoch 76/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.2997 - accuracy: 0.8980 - val_loss: 1.3224 - val_accuracy: 0.7419
# Epoch 77/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.2117 - accuracy: 0.9184 - val_loss: 1.8820 - val_accuracy: 0.6452
# Epoch 78/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1722 - accuracy: 0.9592 - val_loss: 1.3885 - val_accuracy: 0.7097
# Epoch 79/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.3092 - accuracy: 0.8776 - val_loss: 0.6227 - val_accuracy: 0.7419
# Epoch 80/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0601 - accuracy: 0.9796 - val_loss: 0.8300 - val_accuracy: 0.7742
# Epoch 81/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1734 - accuracy: 0.9388 - val_loss: 2.3867 - val_accuracy: 0.6774
# Epoch 82/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1816 - accuracy: 0.9184 - val_loss: 3.2098 - val_accuracy: 0.7097
# Epoch 83/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.2443 - accuracy: 0.8776 - val_loss: 0.7244 - val_accuracy: 0.7742
# Epoch 84/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.3699 - accuracy: 0.8571 - val_loss: 0.2914 - val_accuracy: 0.8387
# Epoch 85/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1063 - accuracy: 0.9796 - val_loss: 0.4917 - val_accuracy: 0.8387
# Epoch 86/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1644 - accuracy: 0.9592 - val_loss: 0.6529 - val_accuracy: 0.8387
# Epoch 87/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1220 - accuracy: 0.9796 - val_loss: 2.7185 - val_accuracy: 0.7419
# Epoch 88/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0899 - accuracy: 0.9592 - val_loss: 2.9460 - val_accuracy: 0.7419
# Epoch 89/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0864 - accuracy: 0.9592 - val_loss: 1.5734 - val_accuracy: 0.7742
# Epoch 90/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.4462 - accuracy: 0.8571 - val_loss: 3.5918 - val_accuracy: 0.6774
# Epoch 91/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.2688 - accuracy: 0.8980 - val_loss: 2.4220 - val_accuracy: 0.6129
# Epoch 92/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0920 - accuracy: 0.9796 - val_loss: 1.7211 - val_accuracy: 0.6452
# Epoch 93/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 1.2075 - val_accuracy: 0.6774
# Epoch 94/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0874 - accuracy: 0.9592 - val_loss: 0.8883 - val_accuracy: 0.7097
# Epoch 95/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.1093 - accuracy: 0.9796 - val_loss: 1.8139 - val_accuracy: 0.7419
# Epoch 96/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.1035 - accuracy: 0.9388 - val_loss: 0.6923 - val_accuracy: 0.8065
# Epoch 97/150
# 7/7 [==============================] - 27s 4s/step - loss: 0.1807 - accuracy: 0.9388 - val_loss: 1.2685 - val_accuracy: 0.6774
# Epoch 98/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0461 - accuracy: 1.0000 - val_loss: 3.0182 - val_accuracy: 0.7419
# Epoch 99/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0886 - accuracy: 1.0000 - val_loss: 0.6949 - val_accuracy: 0.8065
# Epoch 100/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0518 - accuracy: 0.9796 - val_loss: 1.1169 - val_accuracy: 0.6129
# Epoch 101/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1598 - accuracy: 0.9184 - val_loss: 1.4416 - val_accuracy: 0.5806
# Epoch 102/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1143 - accuracy: 0.9592 - val_loss: 1.7532 - val_accuracy: 0.7742
# Epoch 103/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0965 - accuracy: 0.9388 - val_loss: 1.2937 - val_accuracy: 0.7742
# Epoch 104/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1106 - accuracy: 0.9592 - val_loss: 1.4544 - val_accuracy: 0.6452
# Epoch 105/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.3886 - accuracy: 0.8980 - val_loss: 2.0770 - val_accuracy: 0.5484
# Epoch 106/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1421 - accuracy: 0.9388 - val_loss: 2.2134 - val_accuracy: 0.5161
# Epoch 107/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.2246 - accuracy: 0.9388 - val_loss: 2.3295 - val_accuracy: 0.5484
# Epoch 108/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1642 - accuracy: 0.9388 - val_loss: 3.1215 - val_accuracy: 0.4194
# Epoch 109/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.2562 - accuracy: 0.8980 - val_loss: 7.8310 - val_accuracy: 0.2581
# Epoch 110/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.1368 - accuracy: 0.9388 - val_loss: 6.9028 - val_accuracy: 0.3226
# Epoch 111/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1132 - accuracy: 0.9796 - val_loss: 1.0106 - val_accuracy: 0.7742
# Epoch 112/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1498 - accuracy: 0.9388 - val_loss: 1.7445 - val_accuracy: 0.7097
# Epoch 113/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0516 - accuracy: 0.9796 - val_loss: 2.0745 - val_accuracy: 0.6452
# Epoch 114/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0469 - accuracy: 0.9796 - val_loss: 0.8764 - val_accuracy: 0.8065
# Epoch 115/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1010 - accuracy: 0.9388 - val_loss: 2.9041 - val_accuracy: 0.7097
# Epoch 116/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1009 - accuracy: 0.9592 - val_loss: 3.4092 - val_accuracy: 0.6774
# Epoch 117/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1228 - accuracy: 0.9592 - val_loss: 3.8406 - val_accuracy: 0.7097
# Epoch 118/150
# 7/7 [==============================] - 28s 4s/step - loss: 0.2175 - accuracy: 0.9388 - val_loss: 2.8216 - val_accuracy: 0.4516
# Epoch 119/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0396 - accuracy: 1.0000 - val_loss: 2.4121 - val_accuracy: 0.5161
# Epoch 120/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1542 - accuracy: 0.9388 - val_loss: 4.5621 - val_accuracy: 0.4839
# Epoch 121/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0540 - accuracy: 0.9796 - val_loss: 7.7174 - val_accuracy: 0.5484
# Epoch 122/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0547 - accuracy: 1.0000 - val_loss: 2.2296 - val_accuracy: 0.7419
# Epoch 123/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1482 - accuracy: 0.9592 - val_loss: 1.3496 - val_accuracy: 0.8387
# Epoch 124/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0551 - accuracy: 0.9796 - val_loss: 0.8008 - val_accuracy: 0.8710
# Epoch 125/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0861 - accuracy: 0.9592 - val_loss: 1.0175 - val_accuracy: 0.7419
# Epoch 126/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0955 - accuracy: 0.9592 - val_loss: 2.0401 - val_accuracy: 0.6129
# Epoch 127/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0731 - accuracy: 0.9592 - val_loss: 2.7017 - val_accuracy: 0.6452
# Epoch 128/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 3.5335 - val_accuracy: 0.6129
# Epoch 129/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 4.0398 - val_accuracy: 0.6452
# Epoch 130/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0354 - accuracy: 1.0000 - val_loss: 3.1430 - val_accuracy: 0.6774
# Epoch 131/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 2.4810 - val_accuracy: 0.6452
# Epoch 132/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.0241 - val_accuracy: 0.6774
# Epoch 133/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 1.4807 - val_accuracy: 0.6774
# Epoch 134/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1363 - accuracy: 0.9592 - val_loss: 2.1189 - val_accuracy: 0.7742
# Epoch 135/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.2121 - accuracy: 0.9592 - val_loss: 4.5141 - val_accuracy: 0.7097
# Epoch 136/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0341 - accuracy: 1.0000 - val_loss: 9.8253 - val_accuracy: 0.5806
# Epoch 137/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1261 - accuracy: 0.9592 - val_loss: 9.3328 - val_accuracy: 0.5806
# Epoch 138/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0751 - accuracy: 0.9388 - val_loss: 9.3601 - val_accuracy: 0.5484
# Epoch 139/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 5.3465 - val_accuracy: 0.5484
# Epoch 140/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.0360 - accuracy: 0.9796 - val_loss: 3.7314 - val_accuracy: 0.5484
# Epoch 141/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.0800 - accuracy: 0.9592 - val_loss: 1.9448 - val_accuracy: 0.7097
# Epoch 142/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.3952 - accuracy: 0.9184 - val_loss: 3.1154 - val_accuracy: 0.7097
# Epoch 143/150
# 7/7 [==============================] - 26s 4s/step - loss: 0.1129 - accuracy: 0.9796 - val_loss: 8.0905 - val_accuracy: 0.5484
# Epoch 144/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1238 - accuracy: 0.9592 - val_loss: 5.6274 - val_accuracy: 0.6774
# Epoch 145/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.0736 - accuracy: 0.9592 - val_loss: 1.0517 - val_accuracy: 0.8387
# Epoch 146/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.1466 - accuracy: 0.9592 - val_loss: 1.8555 - val_accuracy: 0.6452
# Epoch 147/150
# 7/7 [==============================] - 24s 3s/step - loss: 0.0391 - accuracy: 0.9796 - val_loss: 1.2082 - val_accuracy: 0.7419
# Epoch 148/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1890 - accuracy: 0.9388 - val_loss: 0.7356 - val_accuracy: 0.8065
# Epoch 149/150
# 7/7 [==============================] - 25s 4s/step - loss: 0.1848 - accuracy: 0.9388 - val_loss: 3.1815 - val_accuracy: 0.5484
# Epoch 150/150
# 7/7 [==============================] - 24s 4s/step - loss: 0.1894 - accuracy: 0.9184 - val_loss: 1.2308 - val_accuracy: 0.7097

# %%
import matplotlib.pyplot as plt

# %%
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

# %%
import matplotlib.pyplot as plt 
import numpy 
from sklearn import metrics 
 
actual = numpy.random.binomial(1,.9,size = 1000) 
predicted = numpy.random.binomial(1,.9,size = 1000) 
 
confusion_matrix = metrics.confusion_matrix(actual, predicted) 
 
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True]) 
 
cm_display.plot() 
plt.show()
