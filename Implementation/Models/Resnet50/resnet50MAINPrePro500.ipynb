# %%
# Import libraries
import os
import keras
import pickle
import numpy as np
# Get a ResNet50 model
def resnet50_model(classes=1000, *args, **kwargs):
    # Load a model if we have saved one
    if(os.path.isfile('/content/drive/MyDrive/resnet_50.h5') == True):
        return keras.models.load_model('/content/drive/MyDrive/resnet_50.h5')
    # Create an input layer 
    input = keras.layers.Input(shape=(None, None, 3))
    # Create output layers
    output = keras.layers.ZeroPadding2D(padding=3, name='padding_conv1')(input)
    output = keras.layers.Conv2D(64, (7, 7), strides=(2, 2), use_bias=False, name='conv1')(output)
    output = keras.layers.BatchNormalization(axis=3, epsilon=1e-5, name='bn_conv1')(output)
    output = keras.layers.Activation('relu', name='conv1_relu')(output)
    output = keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='pool1')(output)
    output = conv_block(output, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1))
    output = identity_block(output, 3, [64, 64, 256], stage=2, block='b')
    output = identity_block(output, 3, [64, 64, 256], stage=2, block='c')
    output = conv_block(output, 3, [128, 128, 512], stage=3, block='a')
    output = identity_block(output, 3, [128, 128, 512], stage=3, block='b')
    output = identity_block(output, 3, [128, 128, 512], stage=3, block='c')
    output = identity_block(output, 3, [128, 128, 512], stage=3, block='d')
    output = conv_block(output, 3, [256, 256, 1024], stage=4, block='a')
    output = identity_block(output, 3, [256, 256, 1024], stage=4, block='b')
    output = identity_block(output, 3, [256, 256, 1024], stage=4, block='c')
    output = identity_block(output, 3, [256, 256, 1024], stage=4, block='d')
    output = identity_block(output, 3, [256, 256, 1024], stage=4, block='e')
    output = identity_block(output, 3, [256, 256, 1024], stage=4, block='f')
    output = conv_block(output, 3, [512, 512, 2048], stage=5, block='a')
    output = identity_block(output, 3, [512, 512, 2048], stage=5, block='b')
    output = identity_block(output, 3, [512, 512, 2048], stage=5, block='c')
    output = keras.layers.GlobalAveragePooling2D(name='pool5')(output)
    output = keras.layers.Dense(classes, activation='softmax', name='fc1000')(output)
    # Create a model from input layer and output layers
    model = keras.models.Model(inputs=input, outputs=output, *args, **kwargs)
    # Print model
    print()
    print(model.summary(), '\n')
    # Compile the model
    model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.adam(lr=0.01, clipnorm=0.001), metrics=['accuracy'])
    # Return a model
    return model
# Create an identity block
def identity_block(input, kernel_size, filters, stage, block):
    
    # Variables
    filters1, filters2, filters3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    # Create layers
    output = keras.layers.Conv2D(filters1, (1, 1), kernel_initializer='he_normal', name=conv_name_base + '2a')(input)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2a')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(filters2, kernel_size, padding='same', kernel_initializer='he_normal', name=conv_name_base + '2b')(output)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2b')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(filters3, (1, 1), kernel_initializer='he_normal', name=conv_name_base + '2c')(output)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2c')(output)
    output = keras.layers.add([output, input])
    output = keras.layers.Activation('relu')(output)
    # Return a block
    return output
# Create a convolution block
def conv_block(input, kernel_size, filters, stage, block, strides=(2, 2)):
    # Variables
    filters1, filters2, filters3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    # Create block layers
    output = keras.layers.Conv2D(filters1, (1, 1), strides=strides, kernel_initializer='he_normal', name=conv_name_base + '2a')(input)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2a')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(filters2, kernel_size, padding='same', kernel_initializer='he_normal', name=conv_name_base + '2b')(output)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2b')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(filters3, (1, 1), kernel_initializer='he_normal', name=conv_name_base + '2c')(output)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2c')(output)
    shortcut = keras.layers.Conv2D(filters3, (1, 1), strides=strides, kernel_initializer='he_normal', name=conv_name_base + '1')(input)
    shortcut = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '1')(shortcut)
    output = keras.layers.add([output, shortcut])
    output = keras.layers.Activation('relu')(output)
    # Return a block
    return output

# %%
# Train a model
def train():
    # Variables, 25 epochs so far
    epochs = 500
    batch_size = 3
    train_samples = 10 * 1 # 10 categories with 5000 images in each category
    validation_samples = 10 * 1 # 10 categories with 1000 images in each category
    img_width, img_height = 224, 224
    # Get the model (10 categories)
    model = resnet50_model(10)
    # Create a data generator for training
    train_data_generator = keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255, 
        shear_range=0.2, 
        zoom_range=0.2, 
        horizontal_flip=True)
    # Create a data generator for validation
    validation_data_generator = keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2, 
        horizontal_flip=True)
    # Create a train generator
    train_generator = train_data_generator.flow_from_directory( 
        '/content/drive/MyDrive/prepro/clahee/train', 
        target_size=(img_width, img_height), 
        batch_size=batch_size,
        color_mode='rgb',
        shuffle=True,
        class_mode='categorical')
    # Create a test generator
    validation_generator = validation_data_generator.flow_from_directory( 
        '/content/drive/MyDrive/prepro/clahee/test', 
        target_size=(img_width, img_height), 
        batch_size=batch_size,
        color_mode='rgb',
        shuffle=True,
        class_mode='categorical')
    # Start training, fit the model
    history=model.fit_generator( 
        train_generator, 
        steps_per_epoch=train_samples // batch_size, 
        validation_data=validation_generator, 
        validation_steps=validation_samples // batch_size,
        epochs=epochs)
    # Save model to disk
    model.save('/content/drive/MyDrive/resnet_50.h5')
    print('Saved model to disk!')
    # Get labels
    labels = train_generator.class_indices
    # Invert labels
    classes = {}
    for key, value in labels.items():
        classes[value] = key.capitalize()
    # Save classes to file
    with open('/content/drive/MyDrive/classes.pkl', 'wb') as file:
        pickle.dump(classes, file)
    print('Saved classes to disk!')

# %%
# The main entry point for this module
def main():
    # Train a model
    train()
# Tell python to run main method
if __name__ == '__main__': main()
# Out:
# Found 49 images belonging to 2 classes.
# Found 31 images belonging to 2 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/500
# 3/3 [==============================] - 18s 5s/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.4227 - val_accuracy: 0.8889
# Epoch 2/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.4127 - val_accuracy: 0.8889
# Epoch 3/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.1890 - val_accuracy: 0.6667
# Epoch 4/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 1.3605 - val_accuracy: 0.6667
# Epoch 5/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.7795 - val_accuracy: 0.7778
# Epoch 6/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 1.0000
# Epoch 7/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.9118 - val_accuracy: 0.7778
# Epoch 8/500
# 3/3 [==============================] - 9s 3s/step - loss: 7.0261e-04 - accuracy: 1.0000 - val_loss: 0.6790 - val_accuracy: 0.7778
# Epoch 9/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.3565 - val_accuracy: 0.8889
# Epoch 10/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0307 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 1.0000
# Epoch 11/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.7372 - val_accuracy: 0.6667
# Epoch 12/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.3193 - val_accuracy: 0.8889
# Epoch 13/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.7945 - val_accuracy: 0.7778
# Epoch 14/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.4293 - accuracy: 0.7778 - val_loss: 0.1138 - val_accuracy: 1.0000
# Epoch 15/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.4705 - val_accuracy: 0.8889
# Epoch 16/500
# 3/3 [==============================] - 8s 3s/step - loss: 8.3924e-04 - accuracy: 1.0000 - val_loss: 0.8609 - val_accuracy: 0.7778
# Epoch 17/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.0841 - val_accuracy: 1.0000
# Epoch 18/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 1.4377 - val_accuracy: 0.6667
# Epoch 19/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.8311 - val_accuracy: 0.6667
# Epoch 20/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.2238 - accuracy: 0.8889 - val_loss: 0.2014 - val_accuracy: 0.8889
# Epoch 21/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.6741 - val_accuracy: 0.7778
# Epoch 22/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0389 - accuracy: 1.0000 - val_loss: 0.1602 - val_accuracy: 1.0000
# Epoch 23/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.1957 - val_accuracy: 1.0000
# Epoch 24/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.1396 - accuracy: 0.8571 - val_loss: 0.3183 - val_accuracy: 0.8889
# Epoch 25/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.7778
# Epoch 26/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.4423 - val_accuracy: 0.8889
# Epoch 27/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.1210 - val_accuracy: 0.6667
# Epoch 28/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.3498 - val_accuracy: 0.8889
# Epoch 29/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.1405 - accuracy: 0.8889 - val_loss: 1.1774 - val_accuracy: 0.6667
# Epoch 30/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.8889
# Epoch 31/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3169 - val_accuracy: 0.8889
# Epoch 32/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 1.3068 - val_accuracy: 0.4444
# Epoch 33/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.1496 - accuracy: 0.8571 - val_loss: 1.0785 - val_accuracy: 0.6667
# Epoch 34/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0381 - accuracy: 1.0000 - val_loss: 0.7716 - val_accuracy: 0.7778
# Epoch 35/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.2129 - val_accuracy: 0.6667
# Epoch 36/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.4034 - accuracy: 0.8889 - val_loss: 1.0266 - val_accuracy: 0.5556
# Epoch 37/500
# 3/3 [==============================] - 9s 3s/step - loss: 6.4553e-04 - accuracy: 1.0000 - val_loss: 1.2866 - val_accuracy: 0.6667
# Epoch 38/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.8889
# Epoch 39/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6817 - val_accuracy: 0.7778
# Epoch 40/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.0426 - val_accuracy: 0.5556
# Epoch 41/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.8889
# Epoch 42/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.7629 - val_accuracy: 0.4444
# Epoch 43/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0902 - accuracy: 1.0000 - val_loss: 1.0447 - val_accuracy: 0.5556
# Epoch 44/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.9446 - val_accuracy: 0.6667
# Epoch 45/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3509 - val_accuracy: 0.7778
# Epoch 46/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.4588 - val_accuracy: 0.8889
# Epoch 47/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.1492 - accuracy: 0.8889 - val_loss: 0.7730 - val_accuracy: 0.6667
# Epoch 48/500
# 3/3 [==============================] - 9s 3s/step - loss: 4.3035e-04 - accuracy: 1.0000 - val_loss: 0.3967 - val_accuracy: 0.8889
# Epoch 49/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.2095 - accuracy: 0.8889 - val_loss: 0.3672 - val_accuracy: 0.8889
# Epoch 50/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.2347 - accuracy: 0.8889 - val_loss: 0.3763 - val_accuracy: 0.6667
# Epoch 51/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 1.0000
# Epoch 52/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 1.1067 - val_accuracy: 0.6667
# Epoch 53/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.2447 - accuracy: 0.8889 - val_loss: 0.2211 - val_accuracy: 0.8889
# Epoch 54/500
# 3/3 [==============================] - 9s 4s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3548 - val_accuracy: 0.8889
# Epoch 55/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.6918 - val_accuracy: 0.6667
# Epoch 56/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0598 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 1.0000
# Epoch 57/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5617 - val_accuracy: 0.8889
# Epoch 58/500
# 3/3 [==============================] - 8s 3s/step - loss: 9.7548e-04 - accuracy: 1.0000 - val_loss: 0.3873 - val_accuracy: 0.8889
# Epoch 59/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.5312 - val_accuracy: 0.8889
# Epoch 60/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0833 - accuracy: 1.0000 - val_loss: 1.2696 - val_accuracy: 0.5556
# Epoch 61/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0503 - accuracy: 1.0000 - val_loss: 0.4754 - val_accuracy: 0.8889
# Epoch 62/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.5386 - val_accuracy: 0.8889
# Epoch 63/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.8937 - val_accuracy: 0.6667
# Epoch 64/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.6186 - val_accuracy: 0.6667
# Epoch 65/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.3873 - val_accuracy: 0.6667
# Epoch 66/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.7778
# Epoch 67/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2697 - val_accuracy: 0.7778
# Epoch 68/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.4309 - val_accuracy: 0.8889
# Epoch 69/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0855 - accuracy: 1.0000 - val_loss: 0.2150 - val_accuracy: 0.8889
# Epoch 70/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.3738 - val_accuracy: 0.7778
# Epoch 71/500
# 3/3 [==============================] - 10s 4s/step - loss: 6.5609e-04 - accuracy: 1.0000 - val_loss: 0.7449 - val_accuracy: 0.8889
# Epoch 72/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.1638 - val_accuracy: 1.0000
# Epoch 73/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.7708 - val_accuracy: 0.6667
# Epoch 74/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.8889
# Epoch 75/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.4370 - val_accuracy: 0.8889
# Epoch 76/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0502 - val_accuracy: 1.0000
# Epoch 77/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 1.0000
# Epoch 78/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.1472 - accuracy: 0.8889 - val_loss: 0.9809 - val_accuracy: 0.6667
# Epoch 79/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0746 - accuracy: 1.0000 - val_loss: 0.9378 - val_accuracy: 0.6667
# Epoch 80/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.3534 - val_accuracy: 0.8889
# Epoch 81/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.8889
# Epoch 82/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.9795 - val_accuracy: 0.5556
# Epoch 83/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0380 - accuracy: 1.0000 - val_loss: 0.6374 - val_accuracy: 0.6667
# Epoch 84/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.8160 - val_accuracy: 0.5556
# Epoch 85/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.6469 - val_accuracy: 0.6667
# Epoch 86/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 1.3633 - val_accuracy: 0.5556
# Epoch 87/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 1.0000
# Epoch 88/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 0.5007 - val_accuracy: 0.7778
# Epoch 89/500
# 3/3 [==============================] - 8s 3s/step - loss: 9.7186e-04 - accuracy: 1.0000 - val_loss: 0.6926 - val_accuracy: 0.7778
# Epoch 90/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.2797 - val_accuracy: 0.8889
# Epoch 91/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.6858 - val_accuracy: 0.6667
# Epoch 92/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 1.0000
# Epoch 93/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5241 - val_accuracy: 0.7778
# Epoch 94/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 1.0000
# Epoch 95/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 1.0000
# Epoch 96/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0804 - val_accuracy: 1.0000
# Epoch 97/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4625 - val_accuracy: 0.7778
# Epoch 98/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.4944 - val_accuracy: 0.8889
# Epoch 99/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 1.0000
# Epoch 100/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.3548 - val_accuracy: 0.7778
# Epoch 101/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.1749 - val_accuracy: 0.8889
# Epoch 102/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.1231 - accuracy: 0.8889 - val_loss: 0.0363 - val_accuracy: 1.0000
# Epoch 103/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4828 - val_accuracy: 0.7778
# Epoch 104/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.8889
# Epoch 105/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.1850 - val_accuracy: 0.8889
# Epoch 106/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.8889
# Epoch 107/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0904 - accuracy: 1.0000 - val_loss: 0.2430 - val_accuracy: 0.8889
# Epoch 108/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.8889
# Epoch 109/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.2201 - val_accuracy: 0.8889
# Epoch 110/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.3988 - val_accuracy: 0.8889
# Epoch 111/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.6210 - val_accuracy: 0.7778
# Epoch 112/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0907 - accuracy: 1.0000 - val_loss: 0.5023 - val_accuracy: 0.8889
# Epoch 113/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.5696 - val_accuracy: 0.6667
# Epoch 114/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.5014 - val_accuracy: 0.4444
# Epoch 115/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.6385 - val_accuracy: 0.8889
# Epoch 116/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.2768 - val_accuracy: 0.6667
# Epoch 117/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2166 - val_accuracy: 0.8889
# Epoch 118/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.6141 - val_accuracy: 0.6667
# Epoch 119/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.4331 - val_accuracy: 0.5556
# Epoch 120/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.9561 - val_accuracy: 0.5556
# Epoch 121/500
# 3/3 [==============================] - 8s 3s/step - loss: 6.4424e-04 - accuracy: 1.0000 - val_loss: 0.8060 - val_accuracy: 0.7778
# Epoch 122/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 123/500
# 3/3 [==============================] - 8s 3s/step - loss: 5.2042e-04 - accuracy: 1.0000 - val_loss: 0.3459 - val_accuracy: 0.7778
# Epoch 124/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.7726 - val_accuracy: 0.6667
# Epoch 125/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 126/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.7778
# Epoch 127/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 1.1970 - val_accuracy: 0.6667
# Epoch 128/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3756 - val_accuracy: 0.8889
# Epoch 129/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.7453 - val_accuracy: 0.6667
# Epoch 130/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.8643 - val_accuracy: 0.6667
# Epoch 131/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.8889
# Epoch 132/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.8889
# Epoch 133/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.7001 - val_accuracy: 0.7778
# Epoch 134/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.5556
# Epoch 135/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 1.0000
# Epoch 136/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.1093 - accuracy: 0.8889 - val_loss: 0.8013 - val_accuracy: 0.7778
# Epoch 137/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.8443 - val_accuracy: 0.7778
# Epoch 138/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0813 - accuracy: 1.0000 - val_loss: 0.8893 - val_accuracy: 0.7778
# Epoch 139/500
# 3/3 [==============================] - 9s 3s/step - loss: 4.1924e-04 - accuracy: 1.0000 - val_loss: 1.3391 - val_accuracy: 0.6667
# Epoch 140/500
# 3/3 [==============================] - 9s 3s/step - loss: 7.5622e-04 - accuracy: 1.0000 - val_loss: 0.9094 - val_accuracy: 0.7778
# Epoch 141/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0976 - accuracy: 1.0000 - val_loss: 0.9283 - val_accuracy: 0.6667
# Epoch 142/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2290 - val_accuracy: 0.8889
# Epoch 143/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.6287 - val_accuracy: 0.7778
# Epoch 144/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6611 - val_accuracy: 0.7778
# Epoch 145/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1930 - val_accuracy: 0.8889
# Epoch 146/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.7025 - val_accuracy: 0.8889
# Epoch 147/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.3925 - val_accuracy: 0.8889
# Epoch 148/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.2453 - val_accuracy: 0.8889
# Epoch 149/500
# 3/3 [==============================] - 9s 4s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.4797 - val_accuracy: 0.7778
# Epoch 150/500
# 3/3 [==============================] - 8s 3s/step - loss: 4.2706e-04 - accuracy: 1.0000 - val_loss: 0.3416 - val_accuracy: 0.7778
# Epoch 151/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.4357 - val_accuracy: 0.7778
# Epoch 152/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.6353 - val_accuracy: 0.8889
# Epoch 153/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.8889
# Epoch 154/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.3799 - val_accuracy: 0.8889
# Epoch 155/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.1612 - val_accuracy: 0.8889
# Epoch 156/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.0447 - val_accuracy: 0.6667
# Epoch 157/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.4666 - val_accuracy: 0.7778
# Epoch 158/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 1.0000
# Epoch 159/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0660 - accuracy: 1.0000 - val_loss: 0.3092 - val_accuracy: 0.8889
# Epoch 160/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.3301 - val_accuracy: 0.8889
# Epoch 161/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 1.0000
# Epoch 162/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0497 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 163/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.8889
# Epoch 164/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2982 - val_accuracy: 0.8889
# Epoch 165/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.6341 - val_accuracy: 0.8889
# Epoch 166/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.5003 - val_accuracy: 0.6667
# Epoch 167/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.3971 - val_accuracy: 0.8889
# Epoch 168/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0867 - accuracy: 0.8889 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 169/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 1.0000
# Epoch 170/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 1.0000
# Epoch 171/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4124 - val_accuracy: 0.7778
# Epoch 172/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0695 - accuracy: 1.0000 - val_loss: 0.6309 - val_accuracy: 0.6667
# Epoch 173/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 1.0000
# Epoch 174/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 1.0000
# Epoch 175/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.1464 - accuracy: 0.8889 - val_loss: 0.1087 - val_accuracy: 1.0000
# Epoch 176/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.3507 - val_accuracy: 0.7778
# Epoch 177/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.1920 - val_accuracy: 0.8889
# Epoch 178/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0825 - val_accuracy: 1.0000
# Epoch 179/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.1569 - accuracy: 0.8571 - val_loss: 0.2257 - val_accuracy: 0.7778
# Epoch 180/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4574 - val_accuracy: 0.6667
# Epoch 181/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 1.0000
# Epoch 182/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 183/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.8889
# Epoch 184/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0358 - accuracy: 1.0000 - val_loss: 0.3008 - val_accuracy: 0.8889
# Epoch 185/500
# 3/3 [==============================] - 8s 3s/step - loss: 6.8130e-05 - accuracy: 1.0000 - val_loss: 0.3598 - val_accuracy: 0.7778
# Epoch 186/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.1616 - accuracy: 0.8571 - val_loss: 0.1311 - val_accuracy: 0.8889
# Epoch 187/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.1311 - accuracy: 0.8571 - val_loss: 0.2899 - val_accuracy: 0.8889
# Epoch 188/500
# 3/3 [==============================] - 8s 3s/step - loss: 3.6527e-04 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.8889
# Epoch 189/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.5980 - val_accuracy: 0.7778
# Epoch 190/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 191/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 1.0000
# Epoch 192/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.4215 - val_accuracy: 0.7778
# Epoch 193/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.8889
# Epoch 194/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 195/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 1.0000
# Epoch 196/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0655 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 1.0000
# Epoch 197/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.8889
# Epoch 198/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.4151 - val_accuracy: 0.8889
# Epoch 199/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.8889
# Epoch 200/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0539 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.8889
# Epoch 201/500
# 3/3 [==============================] - 8s 3s/step - loss: 5.2947e-04 - accuracy: 1.0000 - val_loss: 0.3188 - val_accuracy: 0.7778
# Epoch 202/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.1908 - val_accuracy: 0.8889
# Epoch 203/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 204/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.2416 - val_accuracy: 0.8889
# Epoch 205/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.8889
# Epoch 206/500
# 3/3 [==============================] - 8s 3s/step - loss: 7.3923e-04 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 207/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0443 - accuracy: 1.0000 - val_loss: 0.3103 - val_accuracy: 0.7778
# Epoch 208/500
# 3/3 [==============================] - 10s 4s/step - loss: 1.6841e-04 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 1.0000
# Epoch 209/500
# 3/3 [==============================] - 9s 4s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1697 - val_accuracy: 0.8889
# Epoch 210/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 1.0000
# Epoch 211/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2726 - val_accuracy: 0.8889
# Epoch 212/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.8889
# Epoch 213/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.3642 - val_accuracy: 0.7778
# Epoch 214/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.8889
# Epoch 215/500
# 3/3 [==============================] - 9s 3s/step - loss: 6.8306e-04 - accuracy: 1.0000 - val_loss: 0.1805 - val_accuracy: 0.8889
# Epoch 216/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 217/500
# 3/3 [==============================] - 8s 3s/step - loss: 1.7454e-04 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 1.0000
# Epoch 218/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 0.8889
# Epoch 219/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.8889
# Epoch 220/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2696 - val_accuracy: 0.8889
# Epoch 221/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.3260 - val_accuracy: 0.7778
# Epoch 222/500
# 3/3 [==============================] - 9s 3s/step - loss: 9.6544e-04 - accuracy: 1.0000 - val_loss: 0.5731 - val_accuracy: 0.7778
# Epoch 223/500
# 3/3 [==============================] - 9s 3s/step - loss: 1.6732e-04 - accuracy: 1.0000 - val_loss: 0.3062 - val_accuracy: 0.7778
# Epoch 224/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.3026 - val_accuracy: 0.7778
# Epoch 225/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.7778
# Epoch 226/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1816 - val_accuracy: 0.8889
# Epoch 227/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.8889
# Epoch 228/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.5218 - val_accuracy: 0.7778
# Epoch 229/500
# 3/3 [==============================] - 9s 3s/step - loss: 5.2964e-04 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.8889
# Epoch 230/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 1.0000
# Epoch 231/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2658 - val_accuracy: 0.8889
# Epoch 232/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4891 - val_accuracy: 0.8889
# Epoch 233/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0471 - accuracy: 1.0000 - val_loss: 0.2639 - val_accuracy: 0.8889
# Epoch 234/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2167 - val_accuracy: 0.8889
# Epoch 235/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.3563 - val_accuracy: 0.8889
# Epoch 236/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.8889
# Epoch 237/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 1.0000
# Epoch 238/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 239/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0439 - accuracy: 1.0000 - val_loss: 0.3945 - val_accuracy: 0.7778
# Epoch 240/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2175 - val_accuracy: 0.8889
# Epoch 241/500
# 3/3 [==============================] - 9s 4s/step - loss: 1.9673e-04 - accuracy: 1.0000 - val_loss: 0.2023 - val_accuracy: 0.8889
# Epoch 242/500
# 3/3 [==============================] - 9s 4s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 1.0000
# Epoch 243/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 1.0000
# Epoch 244/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0827 - val_accuracy: 1.0000
# Epoch 245/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2343 - val_accuracy: 0.7778
# Epoch 246/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.8889
# Epoch 247/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 1.0000
# Epoch 248/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0529 - val_accuracy: 1.0000
# Epoch 249/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 1.0000
# Epoch 250/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3313 - val_accuracy: 0.7778
# Epoch 251/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4257 - val_accuracy: 0.7778
# Epoch 252/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.3412 - val_accuracy: 0.8889
# Epoch 253/500
# 3/3 [==============================] - 8s 3s/step - loss: 6.9378e-04 - accuracy: 1.0000 - val_loss: 0.2026 - val_accuracy: 0.8889
# Epoch 254/500
# 3/3 [==============================] - 9s 3s/step - loss: 3.7846e-04 - accuracy: 1.0000 - val_loss: 0.8125 - val_accuracy: 0.6667
# Epoch 255/500
# 3/3 [==============================] - 8s 3s/step - loss: 9.7240e-04 - accuracy: 1.0000 - val_loss: 0.2138 - val_accuracy: 0.8889
# Epoch 256/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.6321 - val_accuracy: 0.7778
# Epoch 257/500
# 3/3 [==============================] - 9s 4s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.3535 - val_accuracy: 0.7778
# Epoch 258/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1113 - val_accuracy: 0.8889
# Epoch 259/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.6708 - val_accuracy: 0.6667
# Epoch 260/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.8889
# Epoch 261/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 1.0000
# Epoch 262/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.8889
# Epoch 263/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.5307 - val_accuracy: 0.7778
# Epoch 264/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.4089 - val_accuracy: 0.6667
# Epoch 265/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.8745 - val_accuracy: 0.6667
# Epoch 266/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1817 - val_accuracy: 0.8889
# Epoch 267/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3586 - val_accuracy: 0.8889
# Epoch 268/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.6709 - val_accuracy: 0.6667
# Epoch 269/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3152 - val_accuracy: 0.8889
# Epoch 270/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5055 - val_accuracy: 0.7778
# Epoch 271/500
# 3/3 [==============================] - 8s 3s/step - loss: 9.5997e-05 - accuracy: 1.0000 - val_loss: 0.8380 - val_accuracy: 0.7778
# Epoch 272/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 1.0000
# Epoch 273/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.5770 - val_accuracy: 0.7778
# Epoch 274/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.7276 - val_accuracy: 0.7778
# Epoch 275/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.9449 - val_accuracy: 0.7778
# Epoch 276/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.5009 - val_accuracy: 0.7778
# Epoch 277/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.5354 - val_accuracy: 0.7778
# Epoch 278/500
# 3/3 [==============================] - 8s 3s/step - loss: 2.7562e-04 - accuracy: 1.0000 - val_loss: 0.5584 - val_accuracy: 0.6667
# Epoch 279/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.9013 - val_accuracy: 0.7778
# Epoch 280/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.6688 - val_accuracy: 0.7778
# Epoch 281/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.2686 - accuracy: 0.8889 - val_loss: 0.4825 - val_accuracy: 0.8889
# Epoch 282/500
# 3/3 [==============================] - 8s 3s/step - loss: 9.4534e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.8889
# Epoch 283/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.3975 - val_accuracy: 0.8889
# Epoch 284/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.8889
# Epoch 285/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 1.0000
# Epoch 286/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4318 - val_accuracy: 0.7778
# Epoch 287/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.3145 - val_accuracy: 0.7778
# Epoch 288/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.8889
# Epoch 289/500
# 3/3 [==============================] - 9s 3s/step - loss: 9.7309e-04 - accuracy: 1.0000 - val_loss: 0.5528 - val_accuracy: 0.8889
# Epoch 290/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.0862 - val_accuracy: 1.0000
# Epoch 291/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0426 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.8889
# Epoch 292/500
# 3/3 [==============================] - 8s 3s/step - loss: 1.7108e-04 - accuracy: 1.0000 - val_loss: 0.4548 - val_accuracy: 0.7778
# Epoch 293/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2321 - val_accuracy: 0.8889
# Epoch 294/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 1.0000
# Epoch 295/500
# 3/3 [==============================] - 8s 3s/step - loss: 7.7785e-04 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 1.0000
# Epoch 296/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4414 - val_accuracy: 0.8889
# Epoch 297/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.3962 - val_accuracy: 0.6667
# Epoch 298/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.3205 - val_accuracy: 0.7778
# Epoch 299/500
# 3/3 [==============================] - 8s 3s/step - loss: 5.5833e-04 - accuracy: 1.0000 - val_loss: 1.1447 - val_accuracy: 0.6667
# Epoch 300/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.6414 - val_accuracy: 0.8889
# Epoch 301/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 1.0000
# Epoch 302/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.2424 - val_accuracy: 0.7778
# Epoch 303/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.1875 - val_accuracy: 0.7778
# Epoch 304/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.5266 - val_accuracy: 0.6667
# Epoch 305/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.3389 - val_accuracy: 0.7778
# Epoch 306/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.3186 - val_accuracy: 0.7778
# Epoch 307/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4568 - val_accuracy: 0.8889
# Epoch 308/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.7596 - val_accuracy: 0.7778
# Epoch 309/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4511 - val_accuracy: 0.7778
# Epoch 310/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2811 - val_accuracy: 0.8889
# Epoch 311/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.9279 - val_accuracy: 0.6667
# Epoch 312/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0843 - val_accuracy: 1.0000
# Epoch 313/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4100 - val_accuracy: 0.7778
# Epoch 314/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.8889
# Epoch 315/500
# 3/3 [==============================] - 9s 3s/step - loss: 7.9045e-04 - accuracy: 1.0000 - val_loss: 0.2450 - val_accuracy: 0.8889
# Epoch 316/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2445 - val_accuracy: 0.8889
# Epoch 317/500
# 3/3 [==============================] - 9s 4s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.8889
# Epoch 318/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.8751 - val_accuracy: 0.6667
# Epoch 319/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 1.0000
# Epoch 320/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.5651 - val_accuracy: 0.6667
# Epoch 321/500
# 3/3 [==============================] - 9s 3s/step - loss: 2.9001e-04 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 0.8889
# Epoch 322/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 1.0000
# Epoch 323/500
# 3/3 [==============================] - 9s 3s/step - loss: 3.2987e-04 - accuracy: 1.0000 - val_loss: 0.3513 - val_accuracy: 0.7778
# Epoch 324/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.3663 - val_accuracy: 0.8889
# Epoch 325/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.5409 - val_accuracy: 0.7778
# Epoch 326/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.6857 - val_accuracy: 0.5556
# Epoch 327/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.1778 - val_accuracy: 0.8889
# Epoch 328/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2686 - val_accuracy: 0.8889
# Epoch 329/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 1.0000
# Epoch 330/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.8889
# Epoch 331/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.6693 - val_accuracy: 0.7778
# Epoch 332/500
# 3/3 [==============================] - 9s 3s/step - loss: 6.9467e-04 - accuracy: 1.0000 - val_loss: 0.4587 - val_accuracy: 0.7778
# Epoch 333/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.8213 - val_accuracy: 0.7778
# Epoch 334/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.4943 - val_accuracy: 0.7778
# Epoch 335/500
# 3/3 [==============================] - 8s 3s/step - loss: 9.8952e-04 - accuracy: 1.0000 - val_loss: 0.5838 - val_accuracy: 0.8889
# Epoch 336/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.6526 - val_accuracy: 0.7778
# Epoch 337/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.6980 - val_accuracy: 0.7778
# Epoch 338/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 1.0351 - val_accuracy: 0.6667
# Epoch 339/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.8240 - val_accuracy: 0.6667
# Epoch 340/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.8889
# Epoch 341/500
# ...
# Epoch 388/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0658 - accuracy: 1.0000 - val_loss: 0.2257 - val_accuracy: 0.8889
# Epoch 389/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2629 - val_accuracy: 0.7778
# Epoch 390/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2764 - val_accuracy: 0.8889
# Epoch 391/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 392/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.9764 - val_accuracy: 0.5556
# Epoch 393/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2422 - val_accuracy: 0.7778
# Epoch 394/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.4000 - val_accuracy: 0.7778
# Epoch 395/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.5593 - val_accuracy: 0.8889
# Epoch 396/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 1.0000
# Epoch 397/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0369 - accuracy: 1.0000 - val_loss: 0.9321 - val_accuracy: 0.7778
# Epoch 398/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 0.3341 - val_accuracy: 0.7778
# Epoch 399/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 400/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 0.8889
# Epoch 401/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.4511 - val_accuracy: 0.8889
# Epoch 402/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2723 - val_accuracy: 0.7778
# Epoch 403/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 404/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2680 - val_accuracy: 0.8889
# Epoch 405/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0698 - val_accuracy: 1.0000
# Epoch 406/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3386 - val_accuracy: 0.7778
# Epoch 407/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4214 - val_accuracy: 0.7778
# Epoch 408/500
# 3/3 [==============================] - 8s 3s/step - loss: 8.2395e-04 - accuracy: 1.0000 - val_loss: 0.0580 - val_accuracy: 1.0000
# Epoch 409/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.8439 - val_accuracy: 0.6667
# Epoch 410/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.8889
# Epoch 411/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1621 - val_accuracy: 0.8889
# Epoch 412/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.8889
# Epoch 413/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.6048 - val_accuracy: 0.7778
# Epoch 414/500
# 3/3 [==============================] - 7s 3s/step - loss: 4.0698e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 1.0000
# Epoch 415/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.6571 - val_accuracy: 0.7778
# Epoch 416/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2525 - val_accuracy: 0.8889
# Epoch 417/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 1.0000
# Epoch 418/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.3552 - val_accuracy: 0.8889
# Epoch 419/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.3009 - val_accuracy: 0.7778
# Epoch 420/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2586 - val_accuracy: 0.7778
# Epoch 421/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.3053 - val_accuracy: 0.8889
# Epoch 422/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.8889
# Epoch 423/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0928 - accuracy: 1.0000 - val_loss: 0.6531 - val_accuracy: 0.7778
# Epoch 424/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2672 - val_accuracy: 0.8889
# Epoch 425/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.8889
# Epoch 426/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.8498 - val_accuracy: 0.7778
# Epoch 427/500
# 3/3 [==============================] - 11s 4s/step - loss: 7.1824e-04 - accuracy: 1.0000 - val_loss: 0.3705 - val_accuracy: 0.7778
# Epoch 428/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6426 - val_accuracy: 0.6667
# Epoch 429/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2375 - val_accuracy: 0.8889
# Epoch 430/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.7093 - val_accuracy: 0.8889
# Epoch 431/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3215 - val_accuracy: 0.8889
# Epoch 432/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.7778
# Epoch 433/500
# 3/3 [==============================] - 9s 3s/step - loss: 1.1463e-04 - accuracy: 1.0000 - val_loss: 0.2844 - val_accuracy: 0.8889
# Epoch 434/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.6455 - val_accuracy: 0.6667
# Epoch 435/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.8889
# Epoch 436/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3086 - val_accuracy: 0.8889
# Epoch 437/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6500 - val_accuracy: 0.6667
# Epoch 438/500
# 3/3 [==============================] - 7s 3s/step - loss: 2.4956e-04 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.8889
# Epoch 439/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.4889 - val_accuracy: 0.8889
# Epoch 440/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 1.0000
# Epoch 441/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 0.8889
# Epoch 442/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.8889
# Epoch 443/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 444/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 1.0000
# Epoch 445/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3369 - val_accuracy: 0.7778
# Epoch 446/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.3547 - val_accuracy: 0.7778
# Epoch 447/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4358 - val_accuracy: 0.7778
# Epoch 448/500
# 3/3 [==============================] - 9s 3s/step - loss: 4.4432e-04 - accuracy: 1.0000 - val_loss: 0.4664 - val_accuracy: 0.7778
# Epoch 449/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0560 - val_accuracy: 1.0000
# Epoch 450/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.8889
# Epoch 451/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.3020 - val_accuracy: 0.8889
# Epoch 452/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.8889
# Epoch 453/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5906 - val_accuracy: 0.6667
# Epoch 454/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5245 - val_accuracy: 0.7778
# Epoch 455/500
# 3/3 [==============================] - 9s 3s/step - loss: 1.1809e-04 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 1.0000
# Epoch 456/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 1.0000
# Epoch 457/500
# 3/3 [==============================] - 10s 4s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.7018 - val_accuracy: 0.6667
# Epoch 458/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 1.0000
# Epoch 459/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2384 - val_accuracy: 0.8889
# Epoch 460/500
# 3/3 [==============================] - 9s 3s/step - loss: 4.8211e-05 - accuracy: 1.0000 - val_loss: 0.4049 - val_accuracy: 0.6667
# Epoch 461/500
# 3/3 [==============================] - 9s 3s/step - loss: 3.3680e-04 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.8889
# Epoch 462/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.3537 - val_accuracy: 0.7778
# Epoch 463/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0806 - val_accuracy: 1.0000
# Epoch 464/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0507 - val_accuracy: 1.0000
# Epoch 465/500
# 3/3 [==============================] - 9s 3s/step - loss: 3.9385e-04 - accuracy: 1.0000 - val_loss: 0.6791 - val_accuracy: 0.6667
# Epoch 466/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.8889
# Epoch 467/500
# 3/3 [==============================] - 9s 3s/step - loss: 9.9568e-04 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.8889
# Epoch 468/500
# 3/3 [==============================] - 8s 3s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0709 - val_accuracy: 1.0000
# Epoch 469/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.8889
# Epoch 470/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2815 - val_accuracy: 0.7778
# Epoch 471/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 472/500
# 3/3 [==============================] - 7s 2s/step - loss: 5.8167e-04 - accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 1.0000
# Epoch 473/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.7356 - val_accuracy: 0.7778
# Epoch 474/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.8889
# Epoch 475/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0381 - accuracy: 1.0000 - val_loss: 0.2270 - val_accuracy: 0.8889
# Epoch 476/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 1.0000
# Epoch 477/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.6430 - val_accuracy: 0.8889
# Epoch 478/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3464 - val_accuracy: 0.8889
# Epoch 479/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 1.0000
# Epoch 480/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.8889
# Epoch 481/500
# 3/3 [==============================] - 11s 4s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.8889
# Epoch 482/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 1.0000
# Epoch 483/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 1.0000
# Epoch 484/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.8889
# Epoch 485/500
# 3/3 [==============================] - 9s 3s/step - loss: 4.4774e-04 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.8889
# Epoch 486/500
# 3/3 [==============================] - 9s 3s/step - loss: 7.4797e-04 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 1.0000
# Epoch 487/500
# 3/3 [==============================] - 7s 3s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 1.0000
# Epoch 488/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.8889
# Epoch 489/500
# 3/3 [==============================] - 9s 3s/step - loss: 9.3260e-04 - accuracy: 1.0000 - val_loss: 0.5000 - val_accuracy: 0.7778
# Epoch 490/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7857 - val_accuracy: 0.6667
# Epoch 491/500
# 3/3 [==============================] - 9s 3s/step - loss: 6.3128e-04 - accuracy: 1.0000 - val_loss: 0.9423 - val_accuracy: 0.5556
# Epoch 492/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 1.0000
# Epoch 493/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.7600 - val_accuracy: 0.7778
# Epoch 494/500
# 3/3 [==============================] - 10s 3s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.8889
# Epoch 495/500
# 3/3 [==============================] - 7s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3014 - val_accuracy: 0.8889
# Epoch 496/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 1.0000
# Epoch 497/500
# 3/3 [==============================] - 10s 3s/step - loss: 1.0889e-04 - accuracy: 1.0000 - val_loss: 0.8253 - val_accuracy: 0.5556
# Epoch 498/500
# 3/3 [==============================] - 9s 3s/step - loss: 3.1048e-04 - accuracy: 1.0000 - val_loss: 0.8006 - val_accuracy: 0.5556
# Epoch 499/500
# 3/3 [==============================] - 9s 3s/step - loss: 5.2987e-04 - accuracy: 1.0000 - val_loss: 0.4121 - val_accuracy: 0.7778
# Epoch 500/500
# 3/3 [==============================] - 9s 3s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1751 - val_accuracy: 1.0000
# Saved model to disk!
# Saved classes to disk!

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()
